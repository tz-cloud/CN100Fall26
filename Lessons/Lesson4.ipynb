# %% [markdown]
# # Built in math functions

# %%
print( abs(-123) )
print( max(1,3,8.4,-12,-101,143) )
print( min(1,3,8,-12.5,-101,143) )
print( round(12.43433457456,6) )
# Out:
# 123
# 143
# -101
# 12.434335

# %% [markdown]
# # Math Module (Library)
#
# These are mathematical function that were created outside the core language.
#
# You will need to import the module into our programs.

# %%
import math

print(20*'-')

#print( math.floor(-.1))
#print( math.floor(0.0))
#print( math.floor(0.1))
#print( math.floor(0.8))
#print( math.floor(1.0))
#print( math.floor(1.3))
#print( math.floor(1.5))
#print( math.floor(1.8))
# Out:
# --------------------

# %%
print( math.pi)
print( math.e)

print( math.cos(math.pi/2) ) #we need to be careful about the approximation of very small number even zero - NEVER ASSUME
print( round( math.cos(math.pi/2),15) )
# Out:
# 3.141592653589793
# 2.718281828459045
# 6.123233995736766e-17
# 0.0
