# %% [markdown]
# How do we get information from a user?
#
# The **input()** function allows user input.
#
#
# Syntax is **input**(*prompt*) where prompt is a string message to the user
#
# The input() function returns a string.

# %%
# You can check the datatype of a variable using the type() function
f_name = input("Enter your first name: ")
l_name = input("Enter your Last name: ")
age = input("Enter your age: ")

print(f'{f_name} {l_name} is {age} year old.')
# Out:
# Enter your first name: t
# Enter your Last name: g
# Enter your age: 3
# t g is 3 year old.

# %% [markdown]
# What if I need a number from a user to do some calculation?
#
# We will need to convert the string to a number which is either and integer or float(decimial)

# %%
sub_total = float( input("Enter the subtotal: ") )
taxes = float( input("Enter the taxes: ") )
total = sub_total + taxes
print(f' Subtotal: {sub_total} + taxes {taxes} = {total} Total Amt')
# Out:
# Enter the subtotal: 3
# Enter the taxes: .23
#  Subtotal: 3.0 + taxes 0.23 = 3.23 Total Amt

# %% [markdown]
# # Mathematical Operators
# PEMDAS - order of operations
#
# + - adding
# - - subtraction
# * - multiplication
# / - division
# ** - Exponential function

# %%
x=5
y=2
a=2*x+1
print(a)

a = x**3
print(a)

a = x/2
print(a)

a = x**(1/2)
print(a)

#integer division - where we divide 2 number and only get the integer portion
#of the division
print( x//y)
print(15*"#")
#Modulas operator (remander operator) -
print(x%y)
print(11%3)
print(0%3)
# Out:
# 11
# 125
# 2.5
# 2.23606797749979
# 2
# ###############
# 1
# 2
# 0

# %%
#Mathematical Operator Shorthand
x=5
x+=1
print(x)
x-=1
print(x)
x*=2
print(x)
x/=2
print(x)
x%=2
print(x)
# Out:
# 6
# 5
# 10
# 5.0
# 1.0

# %%
#representing fraction (rational numbers)
a = 1/2
print(a)

a=1/3
print(a)

a=1/99
print(a)

a=1/7
print(a)
# Out:
# 0.5
# 0.3333333333333333
# 0.010101010101010102
# 0.14285714285714285

# %% [markdown]
# Problems with floating number(real numbers) and the result arithmetic

# %%
#WHat is : 0.1 + 0.1 + 0.1 = 0.3
a = 0.1
b = a + a + a
c = 0.3
print(b == c)
print(b)

#so how can we deal with this.
# we can round the arithmetic
b = round(a+a+a, 10)
print(b==c)
print(b)
# Out:
# False
# 0.30000000000000004
# True
# 0.3
