# %% [markdown]
# # **Declaring variables in python**
#
# * We used variables to store information that our programs will need.
#
# * Python is completely object oriented
#
# * variables are how store information
#
# * Variables names should have meaningful names. Example:average, total_cost
#
# * variables names must begin with a letter
#
# * variables names are case sensitive. So average and Average are different variables
#
# * variables names can contain upper and lower case letters and underscores '_'
#
# * variables names made up of two or more words should be seperated by an underscore so that the code is easily readable.
#
# * varibles names can not be keywords like: if, for, while, etc. Use: help("keywords") to get a list of python keywords
#
# * Variable Datatypes is determined by python when the variable is assigned

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
# this how we make comments in python, where python will ignore this line.

age = 3                   # integer datatype
loan_rate = 0.0675        # float datatype
imgNum = 1+3j             #Complex number ie, 1+3i where j part is imaginary part
fName = 'Jack'            #string
lName = "Bean"
light_on = True

print(imgNum)
print(light_on)
# Out:
# (1+3j)
# True

# %%
#you can assign different values o different variables in one statement
month, day, year = "Febuary", "Monday", "2023"
print(month,day, year)
# Out:
# Febuary Monday 2023

# %% [markdown]
# Attention to datatypes once the variables are assigned

# %%
temp = 10.23
print(temp)
#z = fName + temp  Creates an error bc we are trying to add float with a string

result = "My age is " + str(age) + " old"
print(result)


# Using an F-String, is a nice way of create a string with holders that you
# can drop in values from variables
age = 5
result2 = f"My age is {age+1} old..."
print(result2)

#if we need to convert a string representing a number to an actual integer we can use int() function
# so we can do a mathematical operation
age = 4
years = "7"
z = age + int(years)
print(z)
# Out:
# 10.23
# My age is 5 old
# My age is 6 old...
# 11

# %%
# you can not convert a string that is not representing a number to
# an actual number...you will get an error as demo below
years = "seven"
z = age + int(years)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-c5f28e066846> in <cell line: 4>()
#       2 # an actual number...you will get an error as demo below
#       3 years = "seven"
# ----> 4 z = age + int(years)
#
# ValueError: invalid literal for int() with base 10: 'seven'
